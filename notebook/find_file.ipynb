# %%
import os
data_folder = 'data20171016'
num_of_files=0
for root,dirs,files in os.walk(data_folder):
    for filename in files:
        fullpath = os.path.join(root,filename)
        numbers = open(fullpath).readlines()
        for number in numbers:
            if number =='42':
                num_of_files+=1
                print fullpath
                print num_of_files

# %%
import os
data_folder = 'data20171016'

for i,(root, dirs, files) in enumerate(os.walk(data_folder, topdown=False)):
    print '%d, %s, %s, %s\n' % (i, root,dirs,files)

# %%
import os
data_folder = 'data20171016'

for i,(root, dirs, files) in enumerate(os.walk(data_folder, topdown=False)):
    if i==650 or i==1:
        print i,root,dirs,files
        for filename in files:
            fullpath = os.path.join(root,filename)
            print 'fullpath:%s' % (fullpath)
            numbers = open(fullpath).readlines()
            print numbers
# Out:
# 1 data20171016\ac [] ['1580.txt', '3041.txt', '3459.txt', '3724.txt', '4804.txt', '485.txt', '4889.txt', '5062.txt', '5688.txt', '5982.txt', '601.txt', '7976.txt', '9565.txt', '9810.txt']
# fullpath:data20171016\ac\1580.txt
# ['44']
# fullpath:data20171016\ac\3041.txt
# ['8970']
# fullpath:data20171016\ac\3459.txt
# ['8403']
# fullpath:data20171016\ac\3724.txt
# ['4705']
# fullpath:data20171016\ac\4804.txt
# ['6987']
# fullpath:data20171016\ac\485.txt
# ['5130']
# fullpath:data20171016\ac\4889.txt
# ['9333']
# fullpath:data20171016\ac\5062.txt
# ['9760']
# fullpath:data20171016\ac\5688.txt
# ['3224']
# fullpath:data20171016\ac\5982.txt
# ['3714']
# fullpath:data20171016\ac\601.txt
# ['2602']
# fullpath:data20171016\ac\7976.txt
# ['5404']
# fullpath:data20171016\ac\9565.txt
# ['1352']
# fullpath:data20171016\ac\9810.txt
# ['8960']
# ...

# %%
data_folder = 'data20171016'
d={}
for root,dirs,files in os.walk(data_folder):
    for filename in files:
        fullpath = os.path.join(root,filename)
        d[fullpath] = os.path.getsize(fullpath)

# %%
sd = sorted(d.items(), key=lambda k:k[1], reverse=True)
for k,v in sd:
    print k,v
# Out:
# data20171016\sl\4979.txt 4
# data20171016\xi\4874.txt 4
# data20171016\ko\6596.txt 4
# data20171016\eo\1435.txt 4
# data20171016\lr\4925.txt 4
# data20171016\zi\65.txt 4
# data20171016\ck\1204.txt 4
# data20171016\rh\3980.txt 4
# data20171016\gv\4989.txt 4
# data20171016\xv\793.txt 4
# data20171016\em\5697.txt 4
# data20171016\kt\7060.txt 4
# data20171016\ws\6015.txt 4
# data20171016\ac\9565.txt 4
# data20171016\br\318.txt 4
# data20171016\sr\7762.txt 4
# data20171016\mu\3179.txt 4
# data20171016\tu\2575.txt 4
# data20171016\lr\9436.txt 4
# data20171016\et\3912.txt 4
# data20171016\lo\258.txt 4
# data20171016\qi\3065.txt 4
# data20171016\ej\2347.txt 4
# data20171016\kq\4653.txt 4
# data20171016\pt\5804.txt 4
# data20171016\wk\3487.txt 4
# data20171016\xu\4338.txt 4
# data20171016\dy\2087.txt 4
# data20171016\am\4449.txt 4
# data20171016\bc\5947.txt 4
# data20171016\ew\35.txt 4
# data20171016\nm\2220.txt 4
# data20171016\nb\1855.txt 4
# data20171016\hn\9468.txt 4
# ...
